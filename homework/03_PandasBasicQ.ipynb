# %% [markdown]
# # 3. Pandas 기초 연습문제

# %% [markdown]
# 1. 딕셔너리를 이용해 아래와 같은 인덱스와 값을 가진 시리즈를 생성하고 출력하시오.
#
# ```
# 학번      202502
# 이름          지민
# 중간고사        92
# dtype: object
# ```

# %% [markdown]
# 2. 딕셔너리를 사용하지 않고 index 매개변수를 이용해 1번과 동일한 시리즈를 생성하고 출력하시오.

# %% [markdown]
# 3. 딕셔너리를 이용하여 아래와 같은 모양이 되도록 data frame(df)을 생성하시오.
#
# ![image.png](attachment:892b5f20-d2a3-4288-9cdd-df3d7e22d6a6.png)

# %% [markdown]
# 4. 위 데이터프레임에 행을 추가하여 아래와 같은 모양이 되도록 하시오.<br>
# 단 인덱스는 현재 인덱스 최대값의 다음 값이 되도록 한다.
#
# ![image.png](attachment:3988418a-ed80-4570-b02c-c12e53722317.png)

# %% [markdown]
# 5. 위 데이터프레임에서 '정성훈' 학생에 해당하는 행을 삭제한 결과를 새로운 데이터프레임(df2)에 저장하고 출력하시오.

# %% [markdown]
# 6. 위 데이터프레임(df2)으로부터 인덱싱을 이용하여 이름과 중간고사를 추출하시오.

# %% [markdown]
# 7. 행을 삭제하기 전 원래 데이터프레임(df)에 대해 reindex를 이용하여 2, 0, 4, 1, 3 순으로 순서를 변경하고 <br>
# 그 결과를 다시 원래 데이터프레임(df)에 저장하시오. df는 아래와 같아야 함.
#
# ![image.png](attachment:b0e32987-06b0-4a8e-bf1e-af2ea8dd5a9c.png)

# %% [markdown]
# 8. 인덱스가 변경된 데이터프레임(df)에 대해 iloc과 loc을 각각 이용하여 박용택 학생의 record를 추출하시오. <br>
# (iloc으로 한번, loc으로 한번 수행) <br>
# 이후 모든 문제는 인덱스가 변경된 데이터프레임을 기준으로 함

# %% [markdown]
# 9. iloc과 loc을 각각 이용하여 모든 학생의 이름과 중간고사 점수를 추출하시오. (iloc으로 한번, loc으로 한번 수행)

# %% [markdown]
# 10. 중간고사 점수의 평균을 구하시오.

# %% [markdown]
# 11. 중간고사 점수가 가장 낮은 학생의 인덱스 라벨을 구하시오.

# %% [markdown]
# 12. 퀴즈 점수가 가장 높은 학생의 학번을 구하시오.

# %% [markdown]
# 13. 위 데이터프레임의 각 열에 대해서 개수, 평균, 표준편차, 최소최대값 등의 다양한 통계량을 출력하시오.

# %% [markdown]
# 14. 위 데이터프레임을 중간고사 점수에 따라 내림차순으로 정렬하시오.

# %% [markdown]
# 15. 학생 중에서 퀴즈 점수가 평균 이상인 학생들의 이름을 출력하시오.

# %% [markdown]
# 16. 학생 중에서 퀴즈와 중간고사 점수 모두 평균 이상인 학생들의 record를 출력하시오.

# %% [markdown]
# 17. value_counts를 이용하여 트랙 별로 학생의 수를 구하시오.
